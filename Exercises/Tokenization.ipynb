# %% [markdown]
# # TD7 - Vectoring Words the "Right Way"

# %% [markdown]
# Let's install some libraries. Whilst downloading the libraries, we will explain how we can embed vectors better than we did in the RNN TD.

# %% [markdown]
# \- Embed words >>> embed letters :
#
#     "I would rather be able to see the last 50 words than the last 50 characters",
#
#     "With letters, very little notion of distance between characters (is "r" closer to "d" than it is to "c"?"),
#
#     "With letters, if our network has to output words it will spend a lot of time learning how to predict letters so that the whole word makes sense. Let's give it the possibility to output words in a dictionary directly (if you predict dog vs cat, don't put 1000 neurons on the last layer)"
#
# \- In images, if you change the value of an input pixel a little bit, it doesn't change much the image.
#
# \- With words, if you one-hot encode them and you from (1, 0, 0, 0, 0, ...) to (0, 1, 0, 0, 0, 0, ...) you go from "a" to "able" (https://i.imgur.com/Z7aF0OS.jpeg).
#
# \- In images, if you output an image very close to what you want (imagine a task of going from black & white to colours), the pixel values are going to be very similar to what you want and there is a way to tell the network "you failed but you're close" or "you failed and you're far from where I'd want you to be".
#
# \- With words, if you one-hot encode them you can just tell the network "you failed" or "yeah that's the right word". But if the network outputs "vehicle" instead "car" no way of saying: "almost!".

# %%
# %pip install scikit-learn
# %pip install wget
# %pip install gensim
# %pip install psutil
# %pip install spacy
# Out:
# Requirement already satisfied: scikit-learn in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: wget in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gensim in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from gensim) (1.14.0)
# Requirement already satisfied: smart_open>=1.8.1 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: psutil in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (5.4.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: spacy in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: numpy>=1.19.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in C:\Users\lhott\AppData\Roaming\Python\Python312\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: wrapt in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\lhott\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->spacy) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Let's download the model (trained on Google News and a latent space of size 300). Whilst downloading the model, we will explain how we can embed vectors better than we did in the RNN TD.

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %% [markdown]
# What does an encoded word look like?

# %%
wv['computer']
# Out:
# array([ 1.07421875e-01, -2.01171875e-01,  1.23046875e-01,  2.11914062e-01,
#        -9.13085938e-02,  2.16796875e-01, -1.31835938e-01,  8.30078125e-02,
#         2.02148438e-01,  4.78515625e-02,  3.66210938e-02, -2.45361328e-02,
#         2.39257812e-02, -1.60156250e-01, -2.61230469e-02,  9.71679688e-02,
#        -6.34765625e-02,  1.84570312e-01,  1.70898438e-01, -1.63085938e-01,
#        -1.09375000e-01,  1.49414062e-01, -4.65393066e-04,  9.61914062e-02,
#         1.68945312e-01,  2.60925293e-03,  8.93554688e-02,  6.49414062e-02,
#         3.56445312e-02, -6.93359375e-02, -1.46484375e-01, -1.21093750e-01,
#        -2.27539062e-01,  2.45361328e-02, -1.24511719e-01, -3.18359375e-01,
#        -2.20703125e-01,  1.30859375e-01,  3.66210938e-02, -3.63769531e-02,
#        -1.13281250e-01,  1.95312500e-01,  9.76562500e-02,  1.26953125e-01,
#         6.59179688e-02,  6.93359375e-02,  1.02539062e-02,  1.75781250e-01,
#        -1.68945312e-01,  1.21307373e-03, -2.98828125e-01, -1.15234375e-01,
#         5.66406250e-02, -1.77734375e-01, -2.08984375e-01,  1.76757812e-01,
#         2.38037109e-02, -2.57812500e-01, -4.46777344e-02,  1.88476562e-01,
#         5.51757812e-02,  5.02929688e-02, -1.06933594e-01,  1.89453125e-01,
#        -1.16210938e-01,  8.49609375e-02, -1.71875000e-01,  2.45117188e-01,
#        -1.73828125e-01, -8.30078125e-03,  4.56542969e-02, -1.61132812e-02,
#        -1.99218750e-01, -7.03125000e-02, -2.43164062e-01, -3.66210938e-02,
#        -7.37304688e-02, -1.77734375e-01,  9.17968750e-02, -1.25000000e-01,
#        -1.65039062e-01, -3.57421875e-01, -2.85156250e-01, -1.66992188e-01,
#         1.97265625e-01, -1.53320312e-01,  2.31933594e-02,  2.06054688e-01,
#         1.80664062e-01, -2.74658203e-02, -1.92382812e-01, -9.61914062e-02,
#        -1.06811523e-02, -4.73632812e-02,  6.54296875e-02, -1.25732422e-02,
#         1.78222656e-02, -8.00781250e-02, -2.59765625e-01,  9.37500000e-02,
#        -7.81250000e-02,  4.68750000e-02, -2.22167969e-02,  1.86767578e-02,
#         3.11279297e-02,  1.04980469e-02, -1.69921875e-01,  2.58789062e-02,
#        -3.41796875e-02, -1.44042969e-02, -5.46875000e-02, -8.78906250e-02,
#         1.96838379e-03,  2.23632812e-01, -1.36718750e-01,  1.75781250e-01,
#        -1.63085938e-01,  1.87500000e-01,  3.44238281e-02, -5.63964844e-02,
#        -2.27689743e-05,  4.27246094e-02,  5.81054688e-02, -1.07910156e-01,
#        -3.88183594e-02, -2.69531250e-01,  3.34472656e-02,  9.81445312e-02,
#         5.63964844e-02,  2.23632812e-01, -5.49316406e-02,  1.46484375e-01,
#         5.93261719e-02, -2.19726562e-01,  6.39648438e-02,  1.66015625e-02,
#         4.56542969e-02,  3.26171875e-01, -3.80859375e-01,  1.70898438e-01,
#         5.66406250e-02, -1.04492188e-01,  1.38671875e-01, -1.57226562e-01,
#         3.23486328e-03, -4.80957031e-02, -2.48046875e-01, -6.20117188e-02],
#       dtype=float32)

# %% [markdown]
# Instea of priting the array, maybe printing its shape, maximum and minimum values will be more insightful

# %%
wv['computer'].shape, wv['computer'].max(), wv['computer'].min(), (wv['computer'] ** 2).sum() ** 0.5
# Out:
# ((300,), 0.421875, -0.53515625, 2.6320024370454678)

# %%
wv['inspiring'].shape, wv['inspiring'].max(), wv['inspiring'].min(), (wv['inspiring'] ** 2).sum() ** 0.5
# Out:
# ((300,), 0.42773438, -0.3515625, 2.52306001751033)

# %% [markdown]
# Let's see the distance between words that are close from a spelling point of view and words that are close from a "lexical" point of view

# %%
wv.distance("Paris", "Party"), wv.distance("car", "cat"), wv.distance("car", "Lamborghini"), wv.distance("car", "vehicle")
# Out:
# (1.0615220293402672,
#  0.7847181558609009,
#  0.48789793252944946,
#  0.21789032220840454)

# %%
wv.most_similar("Nike")
# Out:
# [('Adidas', 0.7950947284698486),
#  ('adidas', 0.7668235898017883),
#  ('NIKE', 0.7274937629699707),
#  ('Nike_NYSE_NKE', 0.6847589015960693),
#  ('Reebok', 0.663459300994873),
#  ('Nike_NKE', 0.6379507184028625),
#  ('Under_Armour', 0.5997496843338013),
#  ('spokeswoman_Yoko_Mizukami', 0.5990645885467529),
#  ('Adidas_ADDDY.PK_news', 0.5953589081764221),
#  ('spokeswoman_Joani_Komlos', 0.5935247540473938)]

# %%
wv.most_similar("Paris")
# Out:
# [('Parisian', 0.6789354681968689),
#  ('Hopital_Europeen_Georges_Pompidou', 0.6536554098129272),
#  ('Spyker_D##_Peking', 0.6336591839790344),
#  ('France', 0.633491039276123),
#  ('Pantheon_Sorbonne', 0.6312517523765564),
#  ('Aeroports_De', 0.621803879737854),
#  ('Grigny_south', 0.6194689273834229),
#  ('Place_Denfert_Rochereau', 0.6028153896331787),
#  ('guest_Olivier_Dolige', 0.6024351119995117),
#  ('Lazard_Freres_Banque', 0.5998712182044983)]

# %%
wv.most_similar_cosmul(positive=["king", "woman"], negative=["man"])
# Out:
# [('queen', 0.9314123392105103),
#  ('monarch', 0.858533501625061),
#  ('princess', 0.8476566076278687),
#  ('Queen_Consort', 0.8150269985198975),
#  ('queens', 0.8099815249443054),
#  ('crown_prince', 0.808997631072998),
#  ('royal_palace', 0.8027306795120239),
#  ('monarchy', 0.801961362361908),
#  ('prince', 0.800979733467102),
#  ('empress', 0.7958388328552246)]

# %%
wv.most_similar_cosmul(positive=["boy", "woman"], negative=["man"])
# Out:
# [('girl', 1.018757939338684),
#  ('mother', 0.9110710024833679),
#  ('teenage_girl', 0.9046094417572021),
#  ('toddler', 0.8983652591705322),
#  ('daughter', 0.8961495757102966),
#  ('child', 0.8923880457878113),
#  ('teenager', 0.8660117387771606),
#  ('niece', 0.8555038571357727),
#  ('schoolgirl', 0.8544197678565979),
#  ('baby', 0.8516771197319031)]

# %%
wv.most_similar_cosmul(positive=["cow", "oink"], negative=["pig"])
# Out:
# [('moos', 0.8037621378898621),
#  ('baa', 0.7783335447311401),
#  ('baaa', 0.777667224407196),
#  ('oinks', 0.7757751941680908),
#  ('mooing', 0.773527979850769),
#  ('mooed', 0.7722421884536743),
#  ('neighs', 0.7689445614814758),
#  ('cows_mooing', 0.7671400904655457),
#  ('whinnies', 0.7667444348335266),
#  ('cock_doodle_doo', 0.7664759159088135)]

# %%
wv.most_similar_cosmul(positive=["cat", "oink"], negative=["pig"])
# Out:
# [('miaowing', 0.821600079536438),
#  ('woofs', 0.8177747130393982),
#  ('kitty_kitty', 0.8145589232444763),
#  ('meowing', 0.8128674030303955),
#  ('woof_woof', 0.8090406060218811),
#  ('Yip_yip', 0.8033258318901062),
#  ('meowed', 0.8021880984306335),
#  ('cock_doodle_doo', 0.8019063472747803),
#  ('chittering', 0.8003867864608765),
#  ('purr', 0.7976775169372559)]

# %%
wv.most_similar_cosmul(positive=["dog", "oink"], negative=["pig"])
# Out:
# [('barks', 0.834601640701294),
#  ('woofs', 0.8272683620452881),
#  ('bark_incessantly', 0.817846953868866),
#  ('barking_loudly', 0.8163576126098633),
#  ('Tail_wagging', 0.8125094771385193),
#  ('cats_meow', 0.810688853263855),
#  ('dogs', 0.8093793988227844),
#  ('barking', 0.8093082904815674),
#  ('woof_woof', 0.8092902302742004),
#  ('pooch', 0.8045751452445984)]

# %%
wv.most_similar_cosmul(positive=["Santa", "oink"], negative=["pig"])
# Out:
# [('HO_HO_HO', 0.9089415073394775),
#  ('ho_ho_hoing', 0.9081220030784607),
#  ('Ho_ho_ho', 0.8999334573745728),
#  ('Santa_elves', 0.887882649898529),
#  ('Mrs._Claus', 0.8841321468353271),
#  ('Santa_Claus', 0.8761659264564514),
#  ('Ho_Ho_Ho', 0.8700059056282043),
#  ('Santa_Mrs._Claus', 0.8698497414588928),
#  ('Ho_Ho_Hos', 0.8630191683769226),
#  ('elves_reindeer', 0.8513056039810181)]
